# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import linear_model

# %%
housing=pd.read_csv("data/HousePrice.csv")

# %%
housing.head()
# Out:
#       area    Price
# 0      2600  550000
# 1      3000  565000
# 2      3200  610000
# 3      3600  680000
# 4      4000  725000

# %%
housing.shape
# Out:
# (5, 2)

# %%
print(housing.columns)
# Out:
# Index(['   area ', 'Price'], dtype='object')

# %%
housing.describe()
# Out:
#              area           Price
# count     5.000000       5.000000
# mean   3280.000000  626000.000000
# std     540.370243   74949.983322
# min    2600.000000  550000.000000
# 25%    3000.000000  565000.000000
# 50%    3200.000000  610000.000000
# 75%    3600.000000  680000.000000
# max    4000.000000  725000.000000

# %%
# %matplotlib inline 
plt.xlabel('Area(sq ft)')
plt.ylabel('Price(US$)')
plt.title('Housing Price vs Area')
plt.scatter(housing['   area '], housing['Price'],color="red", marker='+')
plt.show()

# %%
reg=linear_model.LinearRegression()

# %%
housing.columns = housing.columns.str.strip() # to remove white spaces in column names

# %%
print(housing.columns)
# Out:
# Index(['area', 'Price'], dtype='object')

# %%
reg.fit(housing[['area']],housing.Price)
# Out:
# LinearRegression()

# %%
reg.predict([[4500]])
# Out:
# /Users/deepankarsingh/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([791660.95890411])
