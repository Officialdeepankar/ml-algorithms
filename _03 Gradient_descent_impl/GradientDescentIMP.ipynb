# %%
import numpy as np

import matplotlib.pyplot as plt

# %%
x=np.array([1,2,3,4,5])
y=np.array([5,7,9,11,13])

# %%
# %matplotlib inline
def gradientDes(x,y):
    m_curr=b_curr=0
    iterations=1000
    learning_rate=0.01


    plt.scatter(x,y,color='red',marker='+') 
    plt.show()
    
    for i in range(iterations):
        y_predicted=m_curr*x+b_curr

        plt.plot(x,y_predicted,color='green')
        list1=y-y_predicted
        
        squared_errors=list1**2 
        cost=sum(squared_errors)/len(x)

        md=(-2/len(x))*( sum(x*(y-y_predicted)))
        bd=(-2/len(x))*( sum((y-y_predicted)))


        m_curr=m_curr-learning_rate*md
        b_curr=b_curr-learning_rate*bd

        print(f"After calculation:   m_curr= {m_curr} and b_curr = {b_curr} with cost= {cost}")

# %%
gradientDes(x,y)
# Out:
# After calculation:   m_curr= 0.62 and b_curr = 0.18 with cost= 89.0
# After calculation:   m_curr= 1.0928 and b_curr = 0.3192 with cost= 52.25039999999999
# After calculation:   m_curr= 1.453232 and b_curr = 0.42724799999999996 with cost= 30.83194944
# After calculation:   m_curr= 1.7278860800000002 and b_curr = 0.5115091199999999 with cost= 18.347751350784
# After calculation:   m_curr= 1.9370605952000002 and b_curr = 0.5776057727999999 with cost= 11.070010749324897
# After calculation:   m_curr= 2.096250917888 and b_curr = 0.6298300216319999 with cost= 6.826353152519786
# After calculation:   m_curr= 2.2172859146547204 and b_curr = 0.6714583661260799 with cost= 4.350826141683065
# After calculation:   m_curr= 2.309195511463117 and b_curr = 0.7049920439242751 with cost= 2.9056952040975976
# After calculation:   m_curr= 2.3788729763057748 and b_curr = 0.7323404723580026 with cost= 2.0610450731046615
# After calculation:   m_curr= 2.431580493177024 and b_curr = 0.7549612843324961 with cost= 1.5663423003130599
# After calculation:   m_curr= 2.471335107618129 and b_curr = 0.7739672290552247 with cost= 1.275588281190388
# After calculation:   m_curr= 2.501203350198827 and b_curr = 0.7902077780170325 with cost= 1.1037021437989751
# After calculation:   m_curr= 2.523526146474063 and b_curr = 0.8043314214447622 with cost= 1.0011028556851884
# After calculation:   m_curr= 2.5400905089630834 and b_curr = 0.8168332242274232 with cost= 0.9388969341253388
# After calculation:   m_curr= 2.55226060353756 and b_curr = 0.8280911292050898 with cost= 0.9002465769594267
# After calculation:   m_curr= 2.561077803006991 and b_curr = 0.8383936704087344 with cost= 0.8753394365713272
# After calculation:   m_curr= 2.567337066120929 and b_curr = 0.8479611288201402 with cost= 0.8584572531892551
# After calculation:   m_curr= 2.5716452438451163 and b_curr = 0.8569616822764816 with cost= 0.8462675994905574
# After calculation:   m_curr= 2.574465589262602 and b_curr = 0.865523734000245 with cost= 0.8368283939224842
# After calculation:   m_curr= 2.5761517355848147 and b_curr = 0.8737453239644839 with cost= 0.8290077803438447
