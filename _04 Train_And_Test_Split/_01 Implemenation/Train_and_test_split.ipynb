# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import linear_model

# %%
df=pd.read_csv("data/carprices.csv")

# %%
df.head()
# Out:
#    Mileage  Age(yrs)  Sell Price($)
# 0    69000         6          18000
# 1    35000         3          34000
# 2    57000         5          26100
# 3    22500         2          40000
# 4    46000         4          31500

# %%
print(df.columns)
# Out:
# Index(['Mileage', 'Age(yrs)', 'Sell Price($)'], dtype='object')

# %%
# %matplotlib inline
plt.xlabel("Mileage")
plt.ylabel("Sell Price($)")
plt.scatter(df['Mileage'],df['Sell Price($)'],color="red",marker="+")

# %%
# %matplotlib inline
plt.xlabel("Age(yrs)")
plt.ylabel("Sell Price($)")
plt.scatter(df['Age(yrs)'],df['Sell Price($)'],color="green",marker="+")

# %%
X=df[['Mileage','Age(yrs)']]
print(X)
# Out:
#     Mileage  Age(yrs)
# 0     69000         6
# 1     35000         3
# 2     57000         5
# 3     22500         2
# 4     46000         4
# 5     59000         5
# 6     52000         5
# 7     72000         6
# 8     91000         8
# 9     67000         6
# 10    83000         7
# 11    79000         7
# 12    59000         5
# 13    58780         4
# 14    82450         7
# 15    25400         3
# 16    28000         2
# 17    69000         5
# 18    87600         8
# 19    52000         5

# %%
y=df['Sell Price($)']
print(y)
# Out:
# 0     18000
# 1     34000
# 2     26100
# 3     40000
# 4     31500
# 5     26750
# 6     32000
# 7     19300
# 8     12000
# 9     22000
# 10    18700
# 11    19500
# 12    26000
# 13    27500
# 14    19400
# 15    35000
# 16    35500
# 17    19700
# 18    12800
# 19    28200
# Name: Sell Price($), dtype: int64

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.3)

# %%
print(y_test)
print(X_test)
# Out:
# 5     26750
# 14    19400
# 7     19300
# 6     32000
# 16    35500
# 13    27500
# Name: Sell Price($), dtype: int64
#     Mileage  Age(yrs)
# 5     59000         5
# 14    82450         7
# 7     72000         6
# 6     52000         5
# 16    28000         2
# 13    58780         4

# %%
reg=linear_model.LinearRegression()

# %%
reg.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
reg.predict(X_test)
# Out:
# array([25100.58585928, 16249.97879692, 20264.55566952, 27355.55574953,
#        37031.56798257, 25819.68530657])

# %%
y_test
# Out:
# 5     26750
# 14    19400
# 7     19300
# 6     32000
# 16    35500
# 13    27500
# Name: Sell Price($), dtype: int64

# %%
reg.score(X_test,y_test)
# Out:
# 0.8118052541682823

# %%
reg.predict([[35000	,3]])
# Out:
# /Users/deepankarsingh/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([34128.3691273])

# %%
import pickle

# %%
with open("Car_price_predictor_pickle",'wb') as file:
    pickle.dump(reg,file)

# %%
with open("Car_price_predictor_pickle",'rb') as file:
    Model=pickle.load(file)

# %%
Model.predict([[35000	,3]])
# Out:
# /Users/deepankarsingh/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([34128.3691273])
